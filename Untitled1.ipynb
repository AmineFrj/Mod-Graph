# %%
! pip install pandas as pd
# Out:
# Requirement already satisfied: pandas in /usr/local/lib/python3.6/dist-packages (0.24.2)
# Collecting as
#   Downloading https://files.pythonhosted.org/packages/b4/08/226c133ec497d25a63edb38527c02db093c7d89e6d4cdc91078834486a5d/as-0.1-py3-none-any.whl
# Collecting pd
#   Downloading https://files.pythonhosted.org/packages/0e/35/38af4831c03c44765f7cd87e43ced67c000fa6673ef06739872de07eb00a/pd-0.0.1.tar.gz
# Requirement already satisfied: numpy>=1.12.0 in /usr/local/lib/python3.6/dist-packages (from pandas) (1.16.5)
# Requirement already satisfied: pytz>=2011k in /usr/local/lib/python3.6/dist-packages (from pandas) (2018.9)
# Requirement already satisfied: python-dateutil>=2.5.0 in /usr/local/lib/python3.6/dist-packages (from pandas) (2.5.3)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.6/dist-packages (from python-dateutil>=2.5.0->pandas) (1.12.0)
# Building wheels for collected packages: pd
#   Building wheel for pd (setup.py) ... done
#   Created wheel for pd: filename=pd-0.0.1-cp36-none-any.whl size=6507 sha256=4e394a823a9e9dc026896e01c60b245eb429e61681a0dc15f75a959aef74a5ea
#   Stored in directory: /root/.cache/pip/wheels/b7/26/e7/cda8e7140160193c00ca36c0d7d34bf1289ab3b00fd1708266
# Successfully built pd
# Installing collected packages: as, pd
# Successfully installed as-0.1 pd-0.0.1

# %%
import pandas as pd
data_auteurs=pd.read_csv('Liste_Auteurs_affiliationè_photo.csv',sep='\t')
data_articles=pd.read_csv('export_articles_EGC_2004_2018 (2).csv',sep='\t')

# %%
data_articles.head()
data_articles.columns
# Out:
# Index(['series', 'booktitle', 'year', 'title', 'abstract', 'authors',
#        'pdf1page', 'pdfarticle'],
#       dtype='object')

# %%
len(data_articles)
# Out:
# 1269

# %%
data_articles=data_articles[data_articles['abstract'].notna()]

# %%
len(data_articles)
# Out:
# 1096

# %%
data_articles['title']=data_articles['title'].apply(lambda x: ' '.join(x.lower() for x in x.split() ) )
data_articles['title']
# Out:
# 0       #idéo2017 : une plateforme citoyenne dédiée à ...
# 1       a two level co-clustering algorithm for very l...
# 2       algeospf: un modèle de factorisation basé sur ...
# 3       analyse des sentiments à partir des commentair...
# 4       analyse en rôles sémantiques pour le résumé au...
# 6       apport de la fouille de données pour la préven...
# 7       apport des modèles locaux pour les k-moyennes ...
# 8       apprendre les relations de préférence et de co...
# 9       approche contextuelle par régression pour les ...
# 11      cartes auto-organisatrices incrémentales appli...
# 13      classification de données complexes par global...
# 15      comparaison de mesures de centralité basées su...
# 16      complémentarités de représentations vectoriell...
# 17      contextualisation de singularités en temps-rée...
# 18      contraintes prescriptives compatibles avec owl...
# 19      contribution à l'étude de la distributivité d'...
# 20      découverte de motifs graduels partiellement or...
# 21      définir les catégories de dbpédia avec des règ...
# 23      echantillonnage de motifs séquentiels sous con...
# 25      elaboration et utilisation d'une base de conna...
# 26      élimination des liens inter-langues erronés da...
# 27      et si les réseaux sociaux pouvaient nous aider...
# 28      étiquetage thématique automatisé de corpus par...
# 30      exploration et analyses multi-objectifs de sér...
# 31      extraction de chaînes cohérentes en vue de rec...
# 32      extraction de connaissances sur les défaillanc...
# 34                   fouille de motifs temporels négatifs
# 35      interrogation de données structurellement hété...
# 36      kti-mooc: un système de recommandation pour la...
# 37      l'exploitation de données contextuelles pour l...
#                               ...
# 1230    maintenance de bases de connaissances terminol...
# 1232                           mediating the semantic web
# 1233    mesurer la qualité des règles et de leurs cont...
# 1234                        mesurer les usages d'internet
# 1235    mise en oeuvre des méthodes de fouille de donn...
# 1236    modèle de gestion intégrée des compétences et ...
# 1237    modèle topologique pour l'interrogation des ba...
# 1238    modélisation dynamique et temporelle de l'util...
# 1239    musette : a framework for knowledge capture fr...
# 1240    opac : opérateur d'analyse en ligne basé sur u...
# 1242    outil de représentation des évolutions de comm...
# 1243                             poboc : un algorithme de
# 1246             recherche ciblée de documents sur le web
# 1247    recherche dans de grandes bases d'images fixes...
# 1248    recherche de règles d'association hiérarchique...
# 1250    réduction du coût d'évaluation d'une règle rel...
# 1251    règles d'identification et méthodes de visuali...
# 1252    régression linéaire symbolique avec variables ...
# 1253    relations entre gènes impliqués dans les cance...
# 1254         représentation condensée de motifs émergents
# 1255         représentation de graphes par acp granulaire
# 1256    résumé de cubes de données multidimensionnelle...
# 1258          sélection rapide en apprentissage supervisé
# 1259       sous-ensembles flous définis sur une ontologie
# 1261    un algorithme de génération des itemsets fermé...
# 1264    une méthode pour l'appropriation de savoir-fai...
# 1265    utilisation des graphes de proximité dans le c...
# 1266                    validation de graphes conceptuels
# 1267    veille technologique assistée par la fouille d...
# 1268    vers un entrepôt de données pour la gestion de...
# Name: title, Length: 1096, dtype: object

# %%
import string
data_articles['title']=data_articles['title'].apply(lambda x: ' '.join(x for x in x.split() if not x.isdigit() ))
data_articles['title']=data_articles['title'].str.replace('[^\w\s]'," ")
data_articles['title']
# Out:
# 0        idéo2017   une plateforme citoyenne dédiée à ...
# 1       a two level co clustering algorithm for very l...
# 2       algeospf  un modèle de factorisation basé sur ...
# 3       analyse des sentiments à partir des commentair...
# 4       analyse en rôles sémantiques pour le résumé au...
# 6       apport de la fouille de données pour la préven...
# 7       apport des modèles locaux pour les k moyennes ...
# 8       apprendre les relations de préférence et de co...
# 9       approche contextuelle par régression pour les ...
# 11      cartes auto organisatrices incrémentales appli...
# 13      classification de données complexes par global...
# 15      comparaison de mesures de centralité basées su...
# 16      complémentarités de représentations vectoriell...
# 17      contextualisation de singularités en temps rée...
# 18      contraintes prescriptives compatibles avec owl...
# 19      contribution à l étude de la distributivité d ...
# 20      découverte de motifs graduels partiellement or...
# 21      définir les catégories de dbpédia avec des règ...
# 23      echantillonnage de motifs séquentiels sous con...
# 25      elaboration et utilisation d une base de conna...
# 26      élimination des liens inter langues erronés da...
# 27      et si les réseaux sociaux pouvaient nous aider...
# 28      étiquetage thématique automatisé de corpus par...
# 30      exploration et analyses multi objectifs de sér...
# 31      extraction de chaînes cohérentes en vue de rec...
# 32      extraction de connaissances sur les défaillanc...
# 34                   fouille de motifs temporels négatifs
# 35      interrogation de données structurellement hété...
# 36      kti mooc  un système de recommandation pour la...
# 37      l exploitation de données contextuelles pour l...
#                               ...
# 1230    maintenance de bases de connaissances terminol...
# 1232                           mediating the semantic web
# 1233    mesurer la qualité des règles et de leurs cont...
# 1234                        mesurer les usages d internet
# 1235    mise en oeuvre des méthodes de fouille de donn...
# 1236    modèle de gestion intégrée des compétences et ...
# 1237    modèle topologique pour l interrogation des ba...
# 1238    modélisation dynamique et temporelle de l util...
# 1239    musette   a framework for knowledge capture fr...
# 1240    opac   opérateur d analyse en ligne basé sur u...
# 1242    outil de représentation des évolutions de comm...
# 1243                             poboc   un algorithme de
# 1246             recherche ciblée de documents sur le web
# 1247    recherche dans de grandes bases d images fixes...
# 1248    recherche de règles d association hiérarchique...
# 1250    réduction du coût d évaluation d une règle rel...
# 1251    règles d identification et méthodes de visuali...
# 1252    régression linéaire symbolique avec variables ...
# 1253    relations entre gènes impliqués dans les cance...
# 1254         représentation condensée de motifs émergents
# 1255         représentation de graphes par acp granulaire
# 1256    résumé de cubes de données multidimensionnelle...
# 1258          sélection rapide en apprentissage supervisé
# 1259       sous ensembles flous définis sur une ontologie
# 1261    un algorithme de génération des itemsets fermé...
# 1264    une méthode pour l appropriation de savoir fai...
# 1265    utilisation des graphes de proximité dans le c...
# 1266                    validation de graphes conceptuels
# 1267    veille technologique assistée par la fouille d...
# 1268    vers un entrepôt de données pour la gestion de...
# Name: title, Length: 1096, dtype: object

# %%
import nltk
from nltk.corpus import stopwords
from nltk.tokenize import sent_tokenize, word_tokenize
nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# True

# %%
english_stopwords=set(stopwords.words('english'))
french_stopwords = set(stopwords.words('french'))

# %%
data_articles['title']=data_articles['title'].apply(lambda x: ' '.join(x for x in x.split() if x not in french_stopwords ))
data_articles['title']=data_articles['title'].apply(lambda x: ' '.join(x for x in x.split() if x not in english_stopwords ))

# %%
from sklearn.feature_extraction.text import CountVectorizer
from nltk.tokenize import RegexpTokenizer
#tokenizer to remove unwanted elements from out data like symbols and numbers

cv = CountVectorizer()
text_counts= cv.fit_transform(data_articles['title'])

# %%
M=text_counts.toarray()

# %%
M[M>1]=1

# %%
import numpy as np
np.savetxt('Doc_Term_Matrix.csv',M,delimiter=";")

# %%
A=pd.read_csv("docAut-1.csv",sep="\t")

# %%
AT=A.T

# %%
E=AT.dot(M)

# %%
np.sum(np.sum(E)==0)
# Out:
# 258

# %%
E.dot(E.T)
# Out:
#                             Abdelheq Et-tahir Guettala  ...  Éric Gaussier
# Abdelheq Et-tahir Guettala                         8.0  ...            1.0
# Abdellah Sabry                                     1.0  ...            1.0
# Abdelmajid Ben Hamadou                             0.0  ...            0.0
# Abdelmalek Amine                                   0.0  ...            0.0
# Abdelmalek Toumi                                   1.0  ...            1.0
# Abderrahmane Maaradji                              0.0  ...            0.0
# Abdessamad Imine                                   0.0  ...            0.0
# Adel M. Alimi                                      1.0  ...            1.0
# Adina Magda Florea                                 0.0  ...            0.0
# Adnan El Moussawi                                  0.0  ...            0.0
# Adriana Prado                                      0.0  ...            0.0
# Adrien Gressin                                     2.0  ...            1.0
# Adrien Guille                                      0.0  ...            2.0
# Adrien Martins                                     0.0  ...            0.0
# Aghiles Salah                                      0.0  ...            1.0
# Ahlame Douzal-Chouakria                            0.0  ...            0.0
# Ahmed Amrani                                       0.0  ...            0.0
# Aimene Belfodil                                    0.0  ...            0.0
# Alain Boucher                                      0.0  ...            0.0
# Alain Casali                                       0.0  ...            0.0
# Alain Gély                                         1.0  ...            1.0
# Alain Lelu                                         1.0  ...            1.0
# Alain Simac-Lejeune                                0.0  ...            0.0
# Alain-Jérôme Fougères                              0.0  ...            0.0
# Albert Bifet                                       1.0  ...            1.0
# Aldo Napoli                                        0.0  ...            0.0
# Alexandre Blansché                                 1.0  ...            1.0
# Alexandre Lefevre                                  0.0  ...            0.0
# Alexandre Passant                                  0.0  ...            0.0
# Alexandre Pauchet                                  0.0  ...            0.0
# ...                                                ...  ...            ...
# Wissam Siblini                                     0.0  ...            0.0
# Xavier Aimé                                        0.0  ...            0.0
# Xavier Baril                                       1.0  ...            1.0
# Xavier Denis                                       0.0  ...            0.0
# Xavier Polanco                                     0.0  ...            0.0
# Xinyu Wang                                         1.0  ...            1.0
# Yahia Lebbah                                       0.0  ...            0.0
# Yahia Slimani                                      0.0  ...            0.0
# Yahya Slimani                                      1.0  ...            0.0
# Yakoub Salhi                                       1.0  ...            0.0
# Yann Dauxais                                       0.0  ...            0.0
# Yannick Miras                                      0.0  ...            0.0
# Yannick Prié                                       0.0  ...            0.0
# Yi Yu                                              0.0  ...            0.0
# Yoan Chabot                                        0.0  ...            0.0
# Yoann Pitarch                                      0.0  ...            0.0
# Yoanne Didry                                       1.0  ...            1.0
# Younes Abid                                        0.0  ...            0.0
# Younès Bennani                                     4.0  ...            4.0
# Youssef Chahir                                     0.0  ...            0.0
# Yuan Lin                                           0.0  ...            0.0
# Yue Feng                                           0.0  ...            0.0
# Zaia Alimazighi                                    1.0  ...            1.0
# Zakaria Elberrichi                                 0.0  ...            0.0
# Zhi Cheng                                          0.0  ...            0.0
# Zina Bouattou                                      1.0  ...            1.0
# Zohra Bellahsene                                   0.0  ...            0.0
# Zohra Ben Said                                     3.0  ...            1.0
# Zoltan Miklos                                      0.0  ...            0.0
# Éric Gaussier                                      1.0  ...            8.0
#
# [827 rows x 827 columns]
